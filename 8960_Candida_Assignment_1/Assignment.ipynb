# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 1. You and Fredrick are good friends. Yesterday, Fredrick received credit cards from ABCD Bank. He wants to verify whether his credit card numbers are valid or not. You happen to be great at regex so he is asking for your help!
# A valid credit card from ABCD Bank has the following characteristics:
#
# ► It must start with a 4/5/6.
#
# ► It must contain exactly 16 digits.
#
# ► It must only consist of digits 0 to 9.
#
# ► It may have digits in groups of 4, separated by one hyphen "-".
#
# ► It must NOT use any other separator like ' ' , '_', etc.
#
# ► It must NOT have 4  or more consecutive repeated digits.
#
# **Test cases:**
#
# Valid :
#
# 4578-3456-0978-5069
#
# 6234-2221-1234-8900
#
# Invalid:
#
# 1234-4567-3456
#
# 5678-7777-1345-3456
#
# 4567_5678_3333-4589

# %%
import re
for i in range(int(input())):
    S = input().strip()
    pre_match = re.search(r'^[456]\d{3}(-?)\d{4}\1\d{4}\1\d{4}$',S)
    if pre_match:
        processed_string = "".join(pre_match.group(0).split('-'))
        final_match = re.search(r'(\d)\1{3,}',processed_string)
        if final_match:
            print ('Invalid')  
        else:
            print ('Valid')
    else:
        print ('Invalid')

# %% [markdown]
# 2. Read a file that contains ‘n’ numbers (represented in binary format). Each number is represented by 16 bits and stored on a new line. The program should sort the number in ascending order and write back result in new file.

# %%
f = open('drive/MyDrive/8960_Candida_Python/Assignment 1/raw.txt','r')
numbers = []
for line in f:
  l = line.strip()
  numbers.append(int(l,2))
f.close()

numbers.sort()

f = open('drive/MyDrive/8960_Candida_Python/Assignment 1/sorted.txt','w')
for i in numbers:
  f.write(str(i) + '\n')
f.close()

# %% [markdown]
# 3.

# %%
class Node:
 def __init__(self, data):
  self.data = data
  self.next = None

class LinkedList:
  def __init__(self):
    self.head = None

  def push(self, new_data):
    new_node = Node(new_data)
    new_node.next = self.head
    self.head = new_node
    
  def deleteNode(self, key):
    temp = self.head
    if (temp is not None):
      if (temp.data == key):
        self.head = temp.next
        temp = None
      return
    while(temp is not None):
      if temp.data == key:
        break
      prev = temp
      temp = temp.next
      if(temp == None):
        return
      prev.next = temp.next
      temp = None

  def printList(self):
    temp = self.head
    while(temp):
      print(temp.data , end = ' ')
      temp = temp.next
 
  def removeDuplicates(self):
    temp = self.head
    if temp is None:
      return temp
    while temp.next:
      if temp.data == temp.next.data:
        temp.next = temp.next.next
      else:
        temp = temp.next
    return self.head

   
llist = LinkedList()

llist.push(1)
llist.push(2)
llist.push(2)
llist.push(3)
llist.push(4)
print ("Created Linked List: ")

llist.printList()

print("\n\nLinked List after removing duplicate elements:")
llist.removeDuplicates()
llist.printList()
# Out:
# Created Linked List:
# 4 3 2 2 1
#
# Linked List after removing duplicate elements:
# 4 3 2 1
