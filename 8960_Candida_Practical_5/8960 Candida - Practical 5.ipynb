# %% [markdown]
# **Name : Candida Ruth Noronha**
#
# **Class : SE COMPS B**
#
# **Roll No. : 8960**
#
# **Title : Python Experiment 5**

# %% [markdown]
# **Aim:** To Study Text Processing in Python.
#
# **Problem Statement:**
#
# Create a fragment of text.
#
# 1.	In this fragment, you need to identify the frequency of articles used (i.e., 'a', 'an', 'the').
# 2.	And you also need to identify dates (which might be expressed in a variety of ways such as '15/11/2012','15/11/12', '15th March 1999','15th March 99' or '20th of March, 1999').
#
# **Code :**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import datetime

month=['january','february','march','april','may','june','july','august','september','october','november','december']

file = open("drive/MyDrive/8960_Candida_Python/Practical 5/text_processing.txt")
i=1
total_a, total_an, total_the, total_date = 0, 0, 0, 0
for line in file:
  txt=''.join(e.lower() for e in line.strip() if e.isalnum() or e=='/' or e==' ').split()

  print(" In Paragraph {} : ".format(i))

  freq_a = sum(e=='a' for e in txt)
  print(" The frequency of article 'a' : ",freq_a)
  total_a+=freq_a

  freq_an = sum(e=='an' for e in txt)
  print(" The frequency of article 'an' : ",freq_an)
  total_an+=freq_an

  freq_the = sum(e=='the' for e in txt)
  print(" The frequency of article 'the' : ",freq_the)
  total_the+=freq_the

  no_of_dates = sum(e in month for e in txt)
  date = print(" No. of dates found : ", no_of_dates)
  total_date+=no_of_dates

  matches = datefinder.find_dates(line,strict="True")
  for match in matches:
    print (" Dates found : ",match.strftime("%d %B, %Y"))
  i+=1
  print("\n")

print(" Total 'a' in the file: ",total_a)
print(" Total 'an' in the file: ",total_an)
print(" Total 'the' in the file: ",total_the)
print(" Total dates in the file : ",total_date)
# Out:
#  In Paragraph 1 :
#  The frequency of article 'a' :  1
#  The frequency of article 'an' :  0
#  The frequency of article 'the' :  4
#  No. of dates found :  0
#
#
#  In Paragraph 2 :
#  The frequency of article 'a' :  1
#  The frequency of article 'an' :  0
#  The frequency of article 'the' :  5
#  No. of dates found :  0
#
#
#  In Paragraph 3 :
#  The frequency of article 'a' :  1
#  The frequency of article 'an' :  0
#  The frequency of article 'the' :  6
#  No. of dates found :  0
#
#
#  In Paragraph 4 :
#  The frequency of article 'a' :  1
#  The frequency of article 'an' :  0
#  The frequency of article 'the' :  6
#  No. of dates found :  1
#  Dates found :  10 May, 1857
#
#
#  In Paragraph 5 :
#  The frequency of article 'a' :  4
#  The frequency of article 'an' :  1
#  The frequency of article 'the' :  13
#  No. of dates found :  1
#  Dates found :  16 December, 1773
#
#
#  Total 'a' in the file:  8
#  Total 'an' in the file:  1
#  Total 'the' in the file:  34
# ...
